# %%
import pandas as pd

pd.set_option('display.max_rows', None)        
pd.set_option('display.max_columns', None)     
pd.set_option('display.max_colwidth', None)    
pd.set_option('display.width', None)           # 不限制横向宽度

df = pd.read_stata(r"C:\Users\Yutong Ren\Desktop\Y4\Y4-research-project\UK-Energy-Modelling-Update-main\UK-Energy-Modelling-Update-main\data\Dataset_SE.dta")


df.to_html("full_output.html", index=False)
