# %% [markdown]
# ----
#
# <h1>Renewable Energy Physics MSci Project<span class="tocSkip"></span></h1>
#
#
#
# Author: Rei Suzuki
#
# Last update: 21st March 2025
#
# ----

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Introduction" data-toc-modified-id="Introduction-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Introduction</a></span><ul class="toc-item"><li><span><a href="#Aims-and-Objectives" data-toc-modified-id="Aims-and-Objectives-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Aims and Objectives</a></span></li><li><span><a href="#Key-Data-Sources" data-toc-modified-id="Key-Data-Sources-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Key Data Sources</a></span></li></ul></li><li><span><a href="#UK-Electricity-and-Gas-Demand" data-toc-modified-id="UK-Electricity-and-Gas-Demand-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>UK Electricity and Gas Demand</a></span><ul class="toc-item"><li><span><a href="#Daily-Electricity-Demand-1979-2018" data-toc-modified-id="Daily-Electricity-Demand-1979-2018-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Daily Electricity Demand 1979-2018</a></span></li><li><span><a href="#Daily-Gas-Demand-2018-2023" data-toc-modified-id="Daily-Gas-Demand-2018-2023-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Daily Gas Demand 2018-2023</a></span></li><li><span><a href="#Yearly-Energy-Demand-by-Sector-and-Fuel" data-toc-modified-id="Yearly-Energy-Demand-by-Sector-and-Fuel-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Yearly Energy Demand by Sector and Fuel</a></span><ul class="toc-item"><li><span><a href="#Energy-Demand-by-Sector" data-toc-modified-id="Energy-Demand-by-Sector-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>Energy Demand by Sector</a></span></li></ul></li></ul></li><li><span><a href="#Electricity-Demand-Prediction-Model" data-toc-modified-id="Electricity-Demand-Prediction-Model-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Electricity Demand Prediction Model</a></span><ul class="toc-item"><li><span><a href="#Calculating-Average-Demand-by-Energy-Source-and-Sector" data-toc-modified-id="Calculating-Average-Demand-by-Energy-Source-and-Sector-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Calculating Average Demand by Energy Source and Sector</a></span></li><li><span><a href="#Electrification-Assumptions-by-Energy-Source-and-Sector" data-toc-modified-id="Electrification-Assumptions-by-Energy-Source-and-Sector-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Electrification Assumptions by Energy Source and Sector</a></span><ul class="toc-item"><li><span><a href="#Conversion-to-Electricity-Assumptions" data-toc-modified-id="Conversion-to-Electricity-Assumptions-3.2.1"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span>Conversion to Electricity Assumptions</a></span></li><li><span><a href="#Efficiency-Gain-Assumptions" data-toc-modified-id="Efficiency-Gain-Assumptions-3.2.2"><span class="toc-item-num">3.2.2&nbsp;&nbsp;</span>Efficiency Gain Assumptions</a></span></li><li><span><a href="#Error-Propagation" data-toc-modified-id="Error-Propagation-3.2.3"><span class="toc-item-num">3.2.3&nbsp;&nbsp;</span>Error Propagation</a></span></li></ul></li><li><span><a href="#Electricity-and-Remnant-Fossil-Fuel-Demand-Prediction-Results" data-toc-modified-id="Electricity-and-Remnant-Fossil-Fuel-Demand-Prediction-Results-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Electricity and Remnant Fossil Fuel Demand Prediction Results</a></span></li></ul></li><li><span><a href="#Predicting-Variation-in-Electricity-Demand" data-toc-modified-id="Predicting-Variation-in-Electricity-Demand-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Predicting Variation in Electricity Demand</a></span><ul class="toc-item"><li><span><a href="#Create-Daily-Demand-Averages" data-toc-modified-id="Create-Daily-Demand-Averages-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Create Daily Demand Averages</a></span></li><li><span><a href="#Tile-Average-Electricity-Year" data-toc-modified-id="Tile-Average-Electricity-Year-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Tile Average Electricity Year</a></span></li></ul></li><li><span><a href="#Modelling-Future-Electricity-Supply" data-toc-modified-id="Modelling-Future-Electricity-Supply-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Modelling Future Electricity Supply</a></span><ul class="toc-item"><li><span><a href="#Baseload-Capacity" data-toc-modified-id="Baseload-Capacity-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Baseload Capacity</a></span></li><li><span><a href="#UK-Wind-and-Solar-Potential" data-toc-modified-id="UK-Wind-and-Solar-Potential-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>UK Wind and Solar Potential</a></span></li></ul></li><li><span><a href="#Optimal-Solar-Wind-Mix" data-toc-modified-id="Optimal-Solar-Wind-Mix-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Optimal Solar-Wind Mix</a></span></li><li><span><a href="#Average-Annual-Supply-for-0,-12,-24-GW-Nuclear" data-toc-modified-id="Average-Annual-Supply-for-0,-12,-24-GW-Nuclear-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Average Annual Supply for 0, 12, 24 GW Nuclear</a></span><ul class="toc-item"><li><span><a href="#Renewable-Capacities-and-Renewable-Ratios-Assumptions" data-toc-modified-id="Renewable-Capacities-and-Renewable-Ratios-Assumptions-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Renewable Capacities and Renewable Ratios Assumptions</a></span></li></ul></li><li><span><a href="#Modelling-S-D" data-toc-modified-id="Modelling-S-D-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Modelling S-D</a></span><ul class="toc-item"><li><span><a href="#Net-Energy-Balance-$S-D$" data-toc-modified-id="Net-Energy-Balance-$S-D$-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>Net Energy Balance $S-D$</a></span></li><li><span><a href="#Shortage-and-Surplus-Fractions" data-toc-modified-id="Shortage-and-Surplus-Fractions-8.2"><span class="toc-item-num">8.2&nbsp;&nbsp;</span>Shortage and Surplus Fractions</a></span></li><li><span><a href="#Profiling-Shortages" data-toc-modified-id="Profiling-Shortages-8.3"><span class="toc-item-num">8.3&nbsp;&nbsp;</span>Profiling Shortages</a></span></li></ul></li><li><span><a href="#Energy-Storage" data-toc-modified-id="Energy-Storage-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Energy Storage</a></span><ul class="toc-item"><li><span><a href="#Storage-Levels-and-Remnant-Energies" data-toc-modified-id="Storage-Levels-and-Remnant-Energies-9.1"><span class="toc-item-num">9.1&nbsp;&nbsp;</span>Storage Levels and Remnant Energies</a></span></li></ul></li><li><span><a href="#Interconnectors" data-toc-modified-id="Interconnectors-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Interconnectors</a></span></li><li><span><a href="#Carbon-Capture-and-Storage" data-toc-modified-id="Carbon-Capture-and-Storage-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>Carbon Capture and Storage</a></span><ul class="toc-item"><li><span><a href="#$CO_2$-Tonnage-by-Sector-(2050E)" data-toc-modified-id="$CO_2$-Tonnage-by-Sector-(2050E)-11.1"><span class="toc-item-num">11.1&nbsp;&nbsp;</span>$CO_2$ Tonnage by Sector (2050E)</a></span></li><li><span><a href="#Energy-Content-for-$CO_2$-Removal" data-toc-modified-id="Energy-Content-for-$CO_2$-Removal-11.2"><span class="toc-item-num">11.2&nbsp;&nbsp;</span>Energy Content for $CO_2$ Removal</a></span></li></ul></li><li><span><a href="#Historic-$CO_2$-Emission-Data" data-toc-modified-id="Historic-$CO_2$-Emission-Data-12"><span class="toc-item-num">12&nbsp;&nbsp;</span>Historic $CO_2$ Emission Data</a></span></li></ul></div>

# %% [markdown]
# # Introduction
#
# ## Aims and Objectives
#
# This notebook aims to:
#
# - Estimate electricity demand in 2050 when the UK's economy is expected to be $CO_2$ neutral. The results will be benchmarked against electricity demand figures predicted by FES and AGRFY models.
#
# - Estimate the amount of energy which will be impossible to electrify (for instance the aviation and shipping), and use this to estimate the amount of $CO_2$ that will need to be captured in order to make the UK's economy carbon neutral.
#
# ## Key Data Sources
#
# - UK Energy Demand by Sector and Fuel: https://beis1.shinyapps.io/ecuk/#section-by-fuel [replace this]
#
# - Average Daily Electricity Demand (ERA5 derived time series): https://researchdata.reading.ac.uk/273/

# %%
# import relevant libraries

import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %% [markdown]
# # UK Electricity and Gas Demand

# %% [markdown]
# ##  Daily Electricity Demand 1979-2018
#
# **Importing and Plot Daily Average Demand (GW)**
#
# The data plotted below is from the ERA5 derived time series. It's consist of daily average demand levels, mesasured in GW. The plots illustrate two important trends:
#
# - Month-to-month electricity demand variation is limited, due to relatively low present electrification levels of space heating. As space heating electrifies the demand differences between summer and winter months will be amplified.
#
# - Historical electricity demand is shown to be relatively constant, at slightly below 40 GW. With a shift to net-zero this is expected to increase drastically (see demand predictions later in the notebook).

# %% [markdown]
# ## Daily Gas Demand 2018-2023
#
# Source: National Gas Transmission
#
# - Daily demand actuals, as provided by the National Gas Transmission office, are given in cubic meters. We convert to GWh by multiplying with the energy content figure for natural gas.
# - Data from 01/01/2018 to 17/12/2023

# %% [markdown]
# Put both graphs on the same plot. We will see that:
# - Gas consumption is significantly more seasonal,
# - Total yearly gas consumption is more than 2x higher.

# %% [markdown]
# ## Yearly Energy Demand by Sector and Fuel
#
# - The [dataset used below](https://www.gov.uk/government/publications/energy-and-emissions-projections-2021-to-2040) is published by UK Government's Department for Energy Security and Net-Zero.

# %%
# Reading the .xslx file

demand_by_industry = pd.read_excel("../data/Annex_F_final_energy_demand.xlsx",
                                   sheet_name="Import_Sheet", index_col=[0, 1])

# Calculate the average for the years 2000 to 2002
demand_by_industry_average = demand_by_industry.mean(axis=1)

# %%
demand_by_industry
# Out:
#                                                                   2000  \
# Industry               Energy Source
# Agriculture            Electricity                            4.357994
#                        Natural gas                            1.522018
#                        Petroleum products                     7.368652
#                        Renewables                             0.839105
#                        Solid / manufactured fuels             0.056754
# Commercial Services    Electricity                           69.571009
#                        Natural gas                           64.382052
#                        Petroleum products                     7.174431
#                        Renewables                             0.133280
#                        Solid / manufactured fuels             0.120836
# Residential            Electricity                          111.841988
#                        Natural gas                          369.909014
# ...

# %%
# List of sectors to plot
sectors = ["Agriculture", "Commercial Services", "Residential",
           "Iron & Steel", "Other Industry sectors", "Public services"]

sectors = ["Transport", "Residential",
           "Other Industry sectors", "Commercial Services", "Public services", "Iron & Steel", "Agriculture"]

# %% [markdown]
# ### Energy Demand by Sector

# %%
# Define the sectors

# Consolidate all energy sources (categories) into a single list
categories = demand_by_industry_average.index.get_level_values(1).unique()

plt.figure(figsize=(12, 6), dpi=200)
plt.title("Energy Demand by Sector (TWh), 2000-2022 Average", fontweight="bold")

# Create an array for the x-axis positions of each sector's bar
x = np.arange(len(sectors))

# Plotting each category's data for each sector and stacking them
cumulative_bottom = np.zeros(len(sectors))  # Initialize an array to track the cumulative bottom for stacking

for category in categories:
    values = [demand_by_industry_average.loc[(sector, category),] if (sector, category) in demand_by_industry_average.index else 0 for sector in sectors]
    plt.bar(x, values, bottom=cumulative_bottom, label=category)
    cumulative_bottom += np.array(values)  # Update the cumulative bottom


# Adding the total above each bar with bold text and a bubble
for i, total in enumerate(cumulative_bottom):
    plt.text(x[i], total + 15, f"{round(total, 2)}", ha="center", va="bottom",
             bbox=dict(facecolor="white", edgecolor="black", boxstyle="round,pad=0.5"))


# Adding a bubble in the top left with the grand total
plt.text(-0.5, 750, f"Total: {cumulative_bottom.sum():.2f} TWh", ha="left", va="top",
         bbox=dict(facecolor="white", edgecolor="black", boxstyle="round,pad=0.5"), fontsize=10, fontweight="bold")


# Adjusting x-axis
plt.xticks(x, sectors)
plt.ylabel("Energy Demand (TWh)")
plt.xticks(rotation=45, ha="right")

# Adjusting y-axis
plt.ylim(0, 800)
plt.grid(axis="y")

# Adding the legend
plt.legend(title="Energy Sources")

plt.show()

# %% [markdown]
# The plot above clearly demonstrates the dominance of transport annual energy consumption. For additional clarity, the breakdown of transport energy consumption by transport sector is plotted below.

# %% [markdown]
# # Electricity Demand Prediction Model
#
# Herein the estimate the level of future electricity demand by considering past demand across all fuel sectors. This will be done by:
#
# - Considering current energy demand in sector
# - Estimating the % of electrification for each sector, by fuel type
# - Estimating the *efficiency improvement factor* when the switching from fuel X to electricity

# %% [markdown]
# ## Calculating Average Demand by Energy Source and Sector

# %%
def average_on_interval(dataframe, start_year, end_year):
    """Calculate the average of the values between start_year and end_year (inclusive) for each combination
    of indices in the given DataFrame. Assumes years are integer column headers.

    Parameters:
    dataframe (pd.DataFrame): The DataFrame with data.
    start_year (int): The starting year.
    end_year (int): The ending year.

    Returns:
    pd.DataFrame: A DataFrame with the average values calculated.
    """
    # Selecting the columns for the specified range of years
    columns_for_average = list(range(start_year, end_year + 1))

    # Checking if the specified columns exist in the DataFrame
    if not all(item in dataframe.columns for item in columns_for_average):
        raise ValueError("One or more specified years are not present in the DataFrame columns.")

    # Calculate the average for the specified range of years
    average_df = dataframe[columns_for_average].mean(axis=1)

    return average_df

# %% [markdown]
# And a function to plot demand by fuel with sectors on the x-axis. This is useful if we want to visualize how taking the average demand between different years impacts the demand plot.

# %%
def plot_stacked_bar(dataframe, x_categories, start_year, end_year):
    """Plots the output of the average_on_interval function.
    """
    # Selecting the columns for the specified range of years
    columns_for_average = list(range(start_year, end_year + 1))

    # Checking if the specified columns exist in the DataFrame
    if not all(item in dataframe.columns for item in columns_for_average):
        raise ValueError("One or more specified years are not present in the DataFrame columns.")

    # Calculate the average for the specified range of years
    average_df = dataframe[columns_for_average].mean(axis=1)

    # Consolidate all energy sources (categories) into a single list
    categories = average_df.index.get_level_values(1).unique()

    # Plot figure ##

    plt.figure(figsize=(12, 6), dpi=200)
    plt.title(f"UK Energy Demand by Sector (TWh), {start_year}-{end_year} Average", fontweight="bold")

    # Create an array for the x-axis positions of each sector's bar
    x = np.arange(len(sectors))

    # Plotting each category's data for each sector and stacking them
    cumulative_bottom = np.zeros(len(sectors))  # Initialize an array to track the cumulative bottom for stacking

    for category in categories:
        values = [average_df.loc[(sector, category),] if (sector, category) in average_df.index else 0 for sector in sectors]
        plt.bar(x, values, bottom=cumulative_bottom, label=category)
        cumulative_bottom += np.array(values)  # Update the cumulative bottom

    # Adding the total above each bar with bold text and a bubble
    for i, total in enumerate(cumulative_bottom):
        plt.text(x[i], total + 15, f"{round(total, 2)}", ha="center", va="bottom",
                 bbox=dict(facecolor="white", edgecolor="black", boxstyle="round,pad=0.5")
                 )

    # Adding a bubble in the top left with the grand total
    plt.text(-0.5, 750, f"Total: {cumulative_bottom.sum():.2f} TWh", ha="left", va="top",
             bbox=dict(facecolor="white", edgecolor="black", boxstyle="round,pad=0.5"),
             fontsize=10, fontweight="bold")

    # Adjusting x-axis
    plt.xticks(x, sectors)
    plt.ylabel("Energy Demand (TWh)")
    plt.xticks(rotation=45)

    # Adjusting y-axis
    plt.ylim(0, 800)
    plt.grid(axis="y")

    # Adding the legend
    plt.legend(title="Energy Sources", fontsize=10)

    plt.show()

# %% [markdown]
# The function output below demonstrates how varying the years between which the average is taken impacts the total demand by sector and in turn the total energy demand.

# %%
# choose start and end years for the model
start_year = 2018
end_year = 2022

plot_stacked_bar(demand_by_industry, sectors, start_year, end_year)

# %% [markdown]
# ## Electrification Assumptions by Energy Source and Sector
#
# What % of energy demand in each sector will be electrified? The aims here are to:
#
# - Create a series of assumptions about the degree of electrification of each fuel, in each sector
# - Package assumptions into a suitable data format to allow multiplication with 20XX-2022 dataframe entries

# %% [markdown]
# ### Conversion to Electricity Assumptions
#
# To what extent are individual sectors expected to electrify the fuels which they presently use? Informed assumptions can be formulated by considering government policies e.g. ban on selling petroleum-powered cars for personal use by 2035 etc. In some cases however, the degree of electrification is less certain.
#
# The demand model will be most sensitive to assumptions related to *Transport* and *Residential* sectors for which relatively informed electrification assumptions can be formulated.
#
# - **Transport**
#
# > 100% electrification of road transport
#
# > 0% electrification of Aviation, Shipping and Rail
#
# - **Residential**
#
# > 100% electrification of residential heating
#
# > 100% electrification of gas stoves
#
#
# - **Other industry sectors**
#
# > 0% electrification of natural gas
#
# > 100% electrification of petroleum products
#
# - **Commerical services**
#
# > 100% electrification of Commercial services (natural gas component of these is primarily assumed to be used for heating)
#
# - **Public services**
#
# > 100% electrification of Public services (natural gas component of these is primarily assumed to used for heating)
#
# - **Iron & Steel**
#
# > 0% electrification
#
# - **Agriculture**
#
# > 0% electrification
#
# ### Efficiency Gain Assumptions
#
# The most important assumptions to make regarding efficiency gains upon switching from fuel X to electricity are: comparing electric vehicle (EV) energy efficiency with internal-combustion engine vehicle (ICEV) energy efficiency and comparing the energy efficiency of gas heating with the energy efficiency of electric heating (assuming the latter will powered by heat pumps).
#
# - The efficiency comparison ratio is given as *electric vehicle efficency ratio* (EVER) given as:
# $$ \text{EVER} = \frac{\left( \frac{1 \text{ gal gas}}{X \text{ "miles per gal gas"}} \right) \left( \frac{115,000 \text{ Btu}}{1 \text{ gal gas}} \right)}{\left( \frac{Y \text{ "kWh per 100 miles"}}{100 \text{ miles}} \right) \left( \frac{3,412 \text{ Btu}}{1 \text{ kWh}} \right)} $$
# A [study published in March 2023](https://www.nrel.gov/docs/fy23osti/84631.pdf) by the *US National Renewable Energy Laboratory* found the average EVER in the US to be $4.4$ i.e. the study found that the average EV light vehicle in the US travels $4.4$ times further per unit of energy than the average registered internal combustion engine light vehicle. The figure was found to be higher ($5.1$) for inter-city travel and lower ($3.6$) for highway testing.
#
#
# - A recent study by the University of Southampton [results summarized here](https://chat.openai.com/c/9ea8c3b1-c182-464b-a178-671eee79042c) showed that heat-pump energy efficiency tends to be c. 4x higher than that of the average gas boiler.
#
# ### Error Propagation
#
# Due to the indefinitive nature of assumptions on electrification rates and efficiency gain factors, all demand prediction results will quoted with error bars which will be obtained using standard techniques of error propagation.
#
# Since the predicted demand $P$ is given by:
#
# $$P = D \times E \times \frac{1}{G}$$
#
# where:
# - $D$ is the present demand (assumed to be known precisely in this context)
# - $E$ is the electrification rate
# - $G$ is the efficiency gain factor
#
# Using the standard partial-derivative formula $\Delta P$, can be expressed as:
#
#
# $$\Delta P = \sqrt{\left(D \times \frac{1}{G} \Delta E\right)^2 + \left(-D \times E \times \frac{1}{G^2} \Delta G\right)^2}$$

# %%
# CO2 emission factors (kgCO2/kWh)

co2_natural_gas = 0.18
co2_petroleum = 0.23
co2_petroleum_rail = 0.23
co2_petroleum_road = 0.23
co2_petroleum_aviation = 0.25
co2_petroleum_shipping = 0.27

# %%
# 1) Conversion rates from fuel X to electricity (0-1) and uncertainties

# Agriculture (Low-sensitivity)
agriculture_electricity = 1
unc_agriculture_electricity = 0

agriculture_petroleum = 1
unc_agriculture_petroleum = 0.1

agriculture_naturalgas = 1
unc_agriculture_naturalgas = 0.1

agriculture_renewables = 1
unc_agriculture_renewables = 0

agriculture_solidmanufacuturedfuels = 1
unc_agriculture_solidmanufacuturedfuels = 0.1

# Commercial Services (Medium-sensitivity)
commercialservices_electricity = 1
unc_commercialservices_electricity = 0

commercialservices_petroleum = 1
unc_commercialservices_petroleum = 0.1

commercialservices_naturalgas = 1
unc_commercialservices_naturalgas = 0.1

commercialservices_renewables = 1
unc_commercialservices_renewables = 0

commercialservices_solidmanufacuturedfuels = 1
unc_commercialservices_solidmanufacuturedfuels = 0

# Residential (High-sensitivity)
residential_electricity = 1
unc_residential_electricity = 0

residential_petroleum = 1
unc_residential_petroleum = 0.1

residential_naturalgas = 1
unc_residential_naturalgas = 0.05

residential_renewables = 1
unc_residential_renewables = 0

residential_solidmanufacuturedfuels = 1
unc_residential_solidmanufacuturedfuels = 0.1


# Iron & Steel (Low-sensitivity)
ironsteel_electricity = 1
unc_ironsteel_electricity = 0

ironsteel_petroleum = 0
unc_ironsteel_petroleum = 0.20

ironsteel_naturalgas = 0
unc_ironsteel_naturalgas = 0.20

ironsteel_renewables = 1
unc_ironsteel_renewables = 0

ironsteel_solidmanufacuturedfuels = 0
unc_ironsteel_solidmanufacuturedfuels = 0.1


# Other Industry (Medium-sensitivity)
otherindustry_electricity = 1
unc_otherindustry_electricity = 0

otherindustry_petroleum = 0
unc_otherindustry_petroleum = 0.1

otherindustry_naturalgas = 0
unc_otherindustry_naturalgas = 0.1

otherindustry_renewables = 1
unc_otherindustry_renewables = 0

otherindustry_solidmanufacuturedfuels = 0
unc_otherindustry_solidmanufacuturedfuels = 0.05

# Public Services (Medium-sensitivity)
publicservices_electricity = 1
unc_publicservices_electricity = 0

publicservices_petroleum = 1
unc_publicservices_petroleum = 0.05

publicservices_naturalgas = 1
unc_publicservices_naturalgas = 0.05

publicservices_renewables = 1
unc_publicservices_renewables = 0

publicservices_solidmanufacuturedfuels = 1
unc_publicservices_solidmanufacuturedfuels = 0.05


# Transport (High-sensitivity)
transport_electricity = 1
unc_transport_electricity = 0.0

transport_petroleum_aviation = 0
unc_transport_petroleum_aviation = 0.1

transport_petroleum_rail = 0
unc_transport_petroleum_rail = 0

transport_petroleum_road = 1
unc_transport_petroleum_road = 0.05

transport_petroleum_shipping = 0
unc_transport_petroleum_shipping = 0

transport_naturalgas = 1
unc_transport_naturalgas = 0

transport_renewables = 1
unc_transport_renewables = 0

transport_solidmanufacuturedfuels = 1
unc_transport_solidmanufacuturedfuels = 0.05


# 2) Efficiency Gain Factors and uncertainties

electricity_to_electricity = 1
unc_electricity_to_electricity = 0

naturalgas_to_electricity = 2.5
unc_naturalgas_to_electricity = 0.5

naturalgas_heating_to_electricity = 3.86  # 3.86 # 4
unc_naturalgas_heating_to_electricity = 1

petroleum_to_electricity = 4.4
unc_petroleum_to_electricity = 1.6

renewables_to_electricity = 1
unc_renewables_to_electricity = 0

solidmanufacuturedfuels_to_electricity = 1
unc_solidmanufacuturedfuels_to_electricity = 0.01


# 3) Create DataFrames

agriculture_df = pd.DataFrame({
    "Energy Source": ["Electricity", "Natural Gas", "Petroleum products", "Renewables", "Solid / manufactured fuels"],
    "Electrification (0-1)": [agriculture_electricity, agriculture_naturalgas, agriculture_petroleum, agriculture_renewables, agriculture_solidmanufacuturedfuels],
    "Efficiency Gain Factor": [electricity_to_electricity, naturalgas_to_electricity, petroleum_to_electricity, renewables_to_electricity, solidmanufacuturedfuels_to_electricity],
    "∆(Electrification)": [unc_agriculture_electricity, unc_agriculture_petroleum, unc_agriculture_naturalgas, unc_agriculture_renewables, unc_agriculture_solidmanufacuturedfuels],
    "∆(EGF)": [unc_electricity_to_electricity, unc_naturalgas_to_electricity,
               unc_petroleum_to_electricity, unc_renewables_to_electricity, unc_solidmanufacuturedfuels_to_electricity],
    "kgCO2/kWh": [0, co2_natural_gas, co2_petroleum, 0, 0]

})

commercialservices_df = pd.DataFrame({
    "Energy Source": ["Electricity", "Natural Gas", "Petroleum products", "Renewables", "Solid / manufactured fuels"],
    "Electrification (0-1)": [commercialservices_electricity, commercialservices_naturalgas, commercialservices_petroleum, commercialservices_renewables, commercialservices_solidmanufacuturedfuels],
    "Efficiency Gain Factor": [electricity_to_electricity, naturalgas_heating_to_electricity, petroleum_to_electricity, renewables_to_electricity, solidmanufacuturedfuels_to_electricity],
    "∆(Electrification)": [unc_commercialservices_electricity, unc_commercialservices_petroleum, unc_commercialservices_naturalgas, unc_commercialservices_renewables, unc_commercialservices_solidmanufacuturedfuels],
    "∆(EGF)": [unc_electricity_to_electricity, unc_naturalgas_to_electricity,
               unc_petroleum_to_electricity, unc_renewables_to_electricity, unc_solidmanufacuturedfuels_to_electricity],
    "kgCO2/kWh": [0, co2_natural_gas, co2_petroleum, 0, 0]

})

residential_df = pd.DataFrame({
    "Energy Source": ["Electricity", "Natural Gas", "Petroleum products", "Renewables", "Solid / manufactured fuels"],
    "Electrification (0-1)": [residential_electricity, residential_naturalgas, residential_petroleum, residential_renewables, residential_solidmanufacuturedfuels],
    "Efficiency Gain Factor": [electricity_to_electricity, naturalgas_heating_to_electricity, petroleum_to_electricity, renewables_to_electricity, solidmanufacuturedfuels_to_electricity],
    "∆(Electrification)": [unc_residential_electricity, unc_residential_petroleum, unc_residential_naturalgas, unc_residential_renewables, unc_residential_solidmanufacuturedfuels],
    "∆(EGF)": [unc_electricity_to_electricity, unc_naturalgas_to_electricity,
               unc_petroleum_to_electricity, unc_renewables_to_electricity, unc_solidmanufacuturedfuels_to_electricity],
    "kgCO2/kWh": [0, co2_natural_gas, co2_petroleum, 0, 0]

})

ironsteel_df = pd.DataFrame({
    "Energy Source": ["Electricity", "Natural Gas", "Petroleum products", "Renewables", "Solid / manufactured fuels"],
    "Electrification (0-1)": [ironsteel_electricity, ironsteel_naturalgas, ironsteel_petroleum, ironsteel_renewables, ironsteel_solidmanufacuturedfuels],
    "Efficiency Gain Factor": [electricity_to_electricity, naturalgas_to_electricity, petroleum_to_electricity, renewables_to_electricity, solidmanufacuturedfuels_to_electricity],
    "∆(Electrification)": [unc_ironsteel_electricity, unc_ironsteel_petroleum, unc_ironsteel_naturalgas, unc_ironsteel_renewables, unc_ironsteel_solidmanufacuturedfuels],
    "∆(EGF)": [unc_electricity_to_electricity, unc_naturalgas_to_electricity,
               unc_petroleum_to_electricity, unc_renewables_to_electricity, unc_solidmanufacuturedfuels_to_electricity],
    "kgCO2/kWh": [0, co2_natural_gas, co2_petroleum, 0, 0]

})

otherindustry_df = pd.DataFrame({
    "Energy Source": ["Electricity", "Natural Gas", "Petroleum products", "Renewables", "Solid / manufactured fuels"],
    "Electrification (0-1)": [otherindustry_electricity, otherindustry_naturalgas, otherindustry_petroleum, otherindustry_renewables, otherindustry_solidmanufacuturedfuels],
    "Efficiency Gain Factor": [electricity_to_electricity, naturalgas_to_electricity, petroleum_to_electricity, renewables_to_electricity, solidmanufacuturedfuels_to_electricity],
    "∆(Electrification)": [unc_otherindustry_electricity, unc_otherindustry_petroleum, unc_otherindustry_naturalgas, unc_otherindustry_renewables, unc_otherindustry_solidmanufacuturedfuels],
    "∆(EGF)": [unc_electricity_to_electricity, unc_naturalgas_to_electricity,
               unc_petroleum_to_electricity, unc_renewables_to_electricity, unc_solidmanufacuturedfuels_to_electricity],
    "kgCO2/kWh": [0, co2_natural_gas, co2_petroleum, 0, 0]

})

publicservices_df = pd.DataFrame({
    "Energy Source": ["Electricity", "Natural Gas", "Petroleum products", "Renewables", "Solid / manufactured fuels"],
    "Electrification (0-1)": [publicservices_electricity, publicservices_naturalgas, publicservices_petroleum, publicservices_renewables, publicservices_solidmanufacuturedfuels],
    "Efficiency Gain Factor": [electricity_to_electricity, naturalgas_heating_to_electricity, petroleum_to_electricity, renewables_to_electricity, solidmanufacuturedfuels_to_electricity],
    "∆(Electrification)": [unc_publicservices_electricity, unc_publicservices_petroleum, unc_publicservices_naturalgas, unc_publicservices_renewables, unc_publicservices_solidmanufacuturedfuels],
    "∆(EGF)": [unc_electricity_to_electricity, unc_naturalgas_to_electricity,
               unc_petroleum_to_electricity, unc_renewables_to_electricity, unc_solidmanufacuturedfuels_to_electricity],
    "kgCO2/kWh": [0, co2_natural_gas, co2_petroleum, 0, 0]

})


transport_df = pd.DataFrame({
    "Energy Source": ["Electricity", "Natural Gas", "Petroleum products (Aviation)", "Petroleum products (Rail)",
                        "Petroleum products (Road transport)", "Petroleum products (Shipping)", "Renewables", "Solid / manufactured fuels"],
    "Electrification (0-1)": [transport_electricity, transport_naturalgas, transport_petroleum_aviation, transport_petroleum_rail,
                         transport_petroleum_road, transport_petroleum_shipping, transport_renewables, transport_solidmanufacuturedfuels],
    "Efficiency Gain Factor": [electricity_to_electricity, naturalgas_to_electricity, petroleum_to_electricity, petroleum_to_electricity, petroleum_to_electricity,
                               petroleum_to_electricity, renewables_to_electricity, solidmanufacuturedfuels_to_electricity],
    "∆(Electrification)": [unc_transport_electricity, unc_transport_petroleum_aviation, unc_transport_petroleum_rail,
                          unc_transport_petroleum_road, unc_transport_petroleum_shipping, unc_transport_naturalgas,
                          unc_transport_renewables, unc_transport_solidmanufacuturedfuels],
    "∆(EGF)": [unc_electricity_to_electricity, unc_naturalgas_to_electricity, unc_petroleum_to_electricity, unc_petroleum_to_electricity, unc_petroleum_to_electricity,
                               unc_petroleum_to_electricity, unc_renewables_to_electricity, unc_solidmanufacuturedfuels_to_electricity],
    "kgCO2/kWh": [0, co2_natural_gas, co2_petroleum_aviation, co2_petroleum_rail, co2_petroleum_road, co2_petroleum_shipping, 0, 0]

})

# %% [markdown]
# ## Electricity and Remnant Fossil Fuel Demand Prediction Results
#
# Now output the results for each sector separately.

# %% [markdown]
# **Remaining Demand for Fossil Fuel Energy**
#
# The electrification assumptions above pointed to the fact that not all sectors of the economy can be viably electrified. Some, like aviation and shipping, will continue to use fossil fuels in the forseable future. Sizing the energy that will continue to originate from fossil fuels is crucial in order to determine the need for future installations of carbon capture and storage capacities.

# %%
def predict_demand(dataframe, start_year, end_year):
    """Return electricity demand results with error bars for each sector.
    """
    # Selecting the columns for the specified range of years
    columns_for_average = list(range(start_year, end_year + 1))

    # Checking if the specified columns exist in the DataFrame
    if not all(item in dataframe.columns for item in columns_for_average):
        raise ValueError("One or more specified years are not present in the DataFrame columns.")

    # Calculate the average for the specified range of years
    average_df = dataframe[columns_for_average].mean(axis=1)

    # Dictionary to hold results for each sector
    sector_results = {
        "Agriculture": agriculture_df,
        "Commercial Services": commercialservices_df,
        "Residential": residential_df,
        "Iron & Steel": ironsteel_df,
        "Other Industry sectors": otherindustry_df,
        "Public services": publicservices_df,
        "Transport": transport_df
    }

    # Calculate for each sector and store in the dictionary
    for sector, df in sector_results.items():

        df["Present Demand (TWh)"] = average_df[sector].values

        df["Predicted Electricity Demand"] = (df["Present Demand (TWh)"] * df["Electrification (0-1)"] *
            1 / df["Efficiency Gain Factor"]
        )

        df["Error Bars (TWh)"] = df["Present Demand (TWh)"] * (
            ((df["∆(Electrification)"] / df["Efficiency Gain Factor"]) ** 2 +
             (df["Electrification (0-1)"] * df["∆(EGF)"] / df["Efficiency Gain Factor"] ** 2) ** 2) ** 0.5
        )

        df["Remaining Fossil-Fuel Demand"] = (df["Present Demand (TWh)"] * (1 - df["Electrification (0-1)"]))

        df["Error Bars Fossil Fuels (TWh)"] = (df["Present Demand (TWh)"] * df["∆(Electrification)"])

        df["CO2 (mt)"] = df["Remaining Fossil-Fuel Demand"] * df["kgCO2/kWh"]  # conveniently, units work out as mt

    return sector_results

# %% [markdown]
# And plot the results.

# %%
start_year = 2018

end_year = 2022

# Using the function to predict demand and calculate error bars
results = predict_demand(demand_by_industry, start_year, end_year)

########
# 1) plot predicted electricity demand

# Sum up the Predicted Electricity Demand and errors for every sector
predicted_electricity_sums = {sector: df["Predicted Electricity Demand"].sum() for sector, df in results.items()}
total_errors_electricity = {sector: np.sqrt((df["Error Bars (TWh)"]**2).sum()) for sector, df in results.items()}  # Error propagation

# Summing up the total predicted electricity demand across all sectors
total_electricity_demand = sum(predicted_electricity_sums.values())

# Plotting the results with error bars
plt.figure(figsize=(12, 6), dpi=200)
bars = plt.bar(predicted_electricity_sums.keys(), predicted_electricity_sums.values(), color="green")

# Add text on each bar in boxes and total sum as text in top left corner
for bar, (sector, error) in zip(bars, total_errors_electricity.items(), strict=False):
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, yval / 2, f"{round(yval, 2)}", ha="center", va="bottom", bbox=dict(facecolor="white", edgecolor="black", boxstyle="round,pad=0.5"))

    # Adding error bars
    plt.errorbar(bar.get_x() + bar.get_width() / 2, yval, yerr=error, fmt="none", capsize=5, color="black")

# Calculating the total error
total_electricity_error = np.sqrt(sum(error**2 for error in total_errors_electricity.values()))

# Adding this error to the total predicted demand display
plt.text(0.02, 0.95, f"Total: {round(total_electricity_demand, 2)} ± {round(total_electricity_error, 2)} TWh", transform=plt.gca().transAxes, ha="left", va="top", bbox=dict(facecolor="white", edgecolor="black", boxstyle="round,pad=0.5", alpha=0.85), fontweight="bold")

# Display total sum of all bars in the top left corner
plt.grid(axis="y")
plt.ylabel("Predicted Electricity Demand (TWh)")
plt.title("Predicted Electricity Demand by Sector (TWh)", fontweight="bold")
plt.xticks(rotation=45)
plt.ylim(0, 300)
plt.savefig("output/Elec demand 2050", bbox_inches="tight")
plt.show()

########
# 2) now plot remaining fossil fuel demand

# Sum up the Predicted Electricity Demand and errors for every sector
predicted_fossilfuels_sums = {sector: df["Remaining Fossil-Fuel Demand"].sum() for sector, df in results.items()}
total_errors_fossilfuels = {sector: np.sqrt((df["Error Bars Fossil Fuels (TWh)"]**2).sum()) for sector, df in results.items()}  # Error propagation

# Summing up the total predicted electricity demand across all sectors
total_fossilfuels_demand = sum(predicted_fossilfuels_sums.values())

# Plotting the results with error bars
plt.figure(figsize=(12, 6), dpi=200)
bars = plt.bar(predicted_fossilfuels_sums.keys(), predicted_fossilfuels_sums.values(), color="grey")

# Add text on each bar in boxes and total sum as text in top left corner
for bar, (sector, error) in zip(bars, total_errors_fossilfuels.items(), strict=False):
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, yval / 2, f"{round(yval, 2)}", ha="center", va="bottom", bbox=dict(facecolor="white", edgecolor="black", boxstyle="round,pad=0.5"))

    # Adding error bars
    plt.errorbar(bar.get_x() + bar.get_width() / 2, yval, yerr=error, fmt="none", capsize=5, color="black")

# Calculating the total error
total_error_fossilfuels = np.sqrt(sum(error**2 for error in total_errors_fossilfuels.values()))

# Adding this error to the total predicted demand display
plt.text(0.02, 0.95, f"Total: {round(total_fossilfuels_demand, 2)} ± {round(total_error_fossilfuels, 2)} TWh", transform=plt.gca().transAxes, ha="left", va="top", bbox=dict(facecolor="white", edgecolor="black", boxstyle="round,pad=0.5", alpha=0.85), fontweight="bold")

# Display total sum of all bars in the top left corner
plt.grid(axis="y")
plt.ylabel("Predicted Fossil Fuel Demand (TWh)")
plt.title("Predicted Fossil Fuel Demand by Sector (TWh)", fontweight="bold")
plt.xticks(rotation=45)
plt.ylim(0, 300)

plt.show()

# %% [markdown]
# Put figures on the same plot.

# %%
# Setting up the figure and axes
fig, axes = plt.subplots(1, 2, figsize=(20, 6), dpi=200)

# Plot 1: Predicted Electricity Demand
axes[0].bar(predicted_electricity_sums.keys(), predicted_electricity_sums.values(), color="green")
for bar, (sector, error) in zip(axes[0].containers[0], total_errors_electricity.items(), strict=False):
    yval = bar.get_height()
    axes[0].text(bar.get_x() + bar.get_width() / 2, yval, f"{round(yval, 2)}", ha="center", va="bottom", bbox=dict(facecolor="white", edgecolor="black", boxstyle="round,pad=0.5"))
    axes[0].errorbar(bar.get_x() + bar.get_width() / 2, yval, yerr=error, fmt="none", capsize=5, color="black")

axes[0].text(0.02, 0.95, f"Total: {round(total_electricity_demand, 2)} ± {round(total_electricity_error, 2)} TWh", transform=axes[0].transAxes, ha="left", va="top", bbox=dict(facecolor="white", edgecolor="black", boxstyle="round,pad=0.5", alpha=0.85), fontweight="bold")
axes[0].set_ylabel("Predicted Electricity Demand (TWh)")
axes[0].set_title("Predicted Electricity Demand by Sector (TWh)", fontweight="bold")
axes[0].tick_params(axis="x", rotation=45)
axes[0].grid(axis="y")
axes[0].set_ylim(0, 300)

# Plot 2: Predicted Fossil Fuel Demand
axes[1].bar(predicted_fossilfuels_sums.keys(), predicted_fossilfuels_sums.values(), color="grey")
for bar, (sector, error) in zip(axes[1].containers[0], total_errors_fossilfuels.items(), strict=False):
    yval = bar.get_height()
    axes[1].text(bar.get_x() + bar.get_width() / 2, yval, f"{round(yval, 2)}", ha="center", va="bottom", bbox=dict(facecolor="white", edgecolor="black", boxstyle="round,pad=0.5"))
    axes[1].errorbar(bar.get_x() + bar.get_width() / 2, yval, yerr=error, fmt="none", capsize=5, color="black")

axes[1].text(0.02, 0.95, f"Total: {round(total_fossilfuels_demand, 2)} ± {round(total_error_fossilfuels, 2)} TWh", transform=axes[1].transAxes, ha="left", va="top", bbox=dict(facecolor="white", edgecolor="black", boxstyle="round,pad=0.5", alpha=0.85), fontweight="bold")
axes[1].set_ylabel("Predicted Fossil Fuel Demand (TWh)")
axes[1].set_title("Predicted Fossil Fuel Demand by Sector (TWh)", fontweight="bold")
axes[1].tick_params(axis="x", rotation=45)
axes[1].grid(axis="y")
axes[1].set_ylim(0, 300)

plt.show()

# %% [markdown]
# # Predicting Variation in Electricity Demand

# %% [markdown]
# We will be prediciting month-to-month demand.

# %%
months = np.array(["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"])

# %%
def print_filtered_data(result_dict, columns_to_print, rows_to_print):
    """Prints specified columns of DataFrames for given rows in each sector.

    :param result_dict: Dictionary of DataFrames, one for each sector.
    :param columns_to_print: List of column names to be printed.
    :param rows_to_print: List of row labels to filter by in the 'Energy Source' column.
    """
    for sector, df in result_dict.items():
        # Filter the DataFrame
        filtered_df = df[df["Energy Source"].isin(rows_to_print)]

        # Check if the DataFrame contains the specified columns
        if all(column in filtered_df.columns for column in columns_to_print):
            # Print the sector name for clarity
            print("___________")
            print(f"{sector}")
            # Print the specified columns in a table format for the filtered rows
            print(filtered_df[columns_to_print].to_string(index=False))
        else:
            # Print a message if the DataFrame does not contain the specified columns
            print(f"{sector} cannot be displayed. Missing columns.")

# %%
# define inputs
result_dict = predict_demand(demand_by_industry, start_year, end_year)
energy_sources = ["Electricity", "Natural Gas", "Petroleum products", "Petroleum products (Aviation)", "Petroleum products (Rail)",
                        "Petroleum products (Road transport)", "Petroleum products (Shipping)", "Renewables", "Solid / manufactured fuels"]
columns = ["Energy Source", "Present Demand (TWh)", "Predicted Electricity Demand"]

# now call function
predicted_demand = print_filtered_data(result_dict, columns, energy_sources)
# Out:
# ___________
# Agriculture
#              Energy Source  Present Demand (TWh)  Predicted Electricity Demand
#                Electricity          4.063566e+00                  4.063566e+00
#                Natural Gas          1.163162e+00                  4.652647e-01
#         Petroleum products          1.035589e+01                  2.353611e+00
#                 Renewables          1.519567e+00                  1.519567e+00
# Solid / manufactured fuels          3.987430e-18                  3.987430e-18
# ___________
# Commercial Services
#              Energy Source  Present Demand (TWh)  Predicted Electricity Demand
#                Electricity             67.961854                     67.961854
#                Natural Gas             54.633108                     14.153655
#         Petroleum products             23.483966                      5.337265
#                 Renewables             13.890240                     13.890240
# ...

# %% [markdown]
# Now we need to know how electricity and natural gas demand vary over the year. For this we need:
# - Month-to-month electricity variation,
# - Month-to-month natural gas variation,
# - Assume petroleum products, solid/manfucatured fuels consumption is constant througout the year

# %% [markdown]
# **Natural Gas fraction of demand by month**
#
# Data on daily gas demand between 2018 and 2023 was supplied by National Gas.

# %%
# Load Natural Gas data
gas_demand_daily = pd.read_excel(
    "../data/UKGasDemand2018-17Dec23.xlsx",
    sheet_name="Sheet1")

# Convert Mcm to GWh
CV = 35.17  # Caloric value of gas in MJ/m3
gas_demand_daily["Demand (TWh)"] = gas_demand_daily["UK Total Demand (mcm)"] * CV * 1 / 3600
gas_demand_daily.head()

# Extract year and month from 'Date'
gas_demand_daily["Year"] = gas_demand_daily["Date"].dt.year
gas_demand_daily["Month"] = gas_demand_daily["Date"].dt.month

# Group by both 'Year' and 'Month', and sum up 'Demand (TWh)'
gas_demand_monthly = gas_demand_daily.groupby(["Year", "Month"])["Demand (TWh)"].sum().reset_index()
gas_demand_yearly = gas_demand_daily.groupby(["Year"])["Demand (TWh)"].sum().reset_index()

# Calculate the monthly average demand
gas_demand_monthly_average = gas_demand_monthly.groupby("Month")["Demand (TWh)"].mean().reset_index()

# Rename the columns
gas_demand_monthly_average.columns = ["Month", "Demand (TWh)"]

gas_demand_monthly_average["FOD (Natural Gas)"] = gas_demand_monthly_average["Demand (TWh)"] / gas_demand_monthly_average["Demand (TWh)"].sum()

# Print the monthly average demand DataFrame
# gas_demand_monthly_average

# %% [markdown]
# **Electricity fraction of demand by month**
#
# The data used below is from the ERA5 derived time series. It's consist of daily average demand levels, mesasured in GW between 1980 and 2018.

# %%
# Load Electricity data
electricity_demand_daily = pd.read_excel(
    "../data/ERA5_full_demand_1979_2018.xlsx",
    sheet_name="Import Sheet")

# Extract year and month and day from 'Date'
electricity_demand_daily["Day"] = electricity_demand_daily["Date"].dt.day
electricity_demand_daily["Year"] = electricity_demand_daily["Date"].dt.year
electricity_demand_daily["Month"] = electricity_demand_daily["Date"].dt.month

# Group by both 'Year' and 'Month', and sum up 'Demand (TWh)'
electricity_demand_monthly = electricity_demand_daily.groupby(["Year", "Month"])["Demand (TWh)"].sum().reset_index()
electricity_demand_yearly = electricity_demand_daily.groupby(["Year"])["Demand (TWh)"].sum().reset_index()

# Calculate the monthly average demand
electricity_demand_monthly_average = electricity_demand_monthly.groupby("Month")["Demand (TWh)"].mean().reset_index()

# Rename the columns
electricity_demand_monthly_average.columns = ["Month", "Demand (TWh)"]

electricity_demand_monthly_average["FOD (Electricity)"] = electricity_demand_monthly_average["Demand (TWh)"] / electricity_demand_monthly_average["Demand (TWh)"].sum()


# Calculate daily average demand
electricity_demand_daily_average = electricity_demand_daily.groupby(["Month", "Day"])["Demand (TWh)"].mean().reset_index()

# %%
# Create a figure with two subplots
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(14, 7), dpi=200)

# Plot for monthly gas demand
gas_bars = axes[0].bar(months, gas_demand_monthly_average["Demand (TWh)"], color="skyblue")

# Annotate the total average monthly gas demand
axes[0].annotate(f"Total: {gas_demand_monthly_average['Demand (TWh)'].sum():.2f} TWh", xy=(0.04, 0.97), xycoords="axes fraction", fontsize=10, color="black",
                 ha="left", va="top", bbox=dict(facecolor="white", edgecolor="black", boxstyle="round,pad=0.3"), fontweight="bold")

# Annotate each bar with its value for gas demand
for i, demand in enumerate(gas_demand_monthly_average["Demand (TWh)"]):
    axes[0].annotate(f"{demand:.2f}", xy=(i, demand / 2), xytext=(0, 5), textcoords="offset points", ha="center", va="bottom",
                 bbox=dict(facecolor="white", edgecolor="black", boxstyle="round", pad=0.3), fontsize=10, rotation=90)

# Add arrow indicating min to max month for gas demand
min_month_gas = months[gas_demand_monthly_average["Demand (TWh)"].idxmin()]
max_month_gas = months[gas_demand_monthly_average["Demand (TWh)"].idxmax()]
min_demand_gas = gas_demand_monthly_average["Demand (TWh)"].min()
max_demand_gas = gas_demand_monthly_average["Demand (TWh)"].max()

arrow_length = max_demand_gas - min_demand_gas
axes[0].annotate(f"$D_{{Max}}/D_{{Min}}$ = {max_demand_gas / min_demand_gas:.2f}", xy=(min_month_gas, min_demand_gas), xytext=(min_month_gas, max_demand_gas),
             arrowprops=dict(facecolor="black", arrowstyle="<|-|>", lw=1.5), ha="center", va="bottom")

# Design elements for gas plot
axes[0].set_title("Monthly Gas Demand (TWh), 2018-2022 Average", fontweight="bold")
axes[0].set_ylabel("Gas Demand (TWh)")
axes[0].set_ylim(0, 115)
axes[0].grid(axis="y")

# Plot for monthly electricity demand
electricity_bars = axes[1].bar(months, electricity_demand_monthly_average["Demand (TWh)"], color="lightblue")

# Annotate the total monthly electricity demand
axes[1].annotate(f"Total: {electricity_demand_monthly_average['Demand (TWh)'].sum():.2f} TWh", xy=(0.04, 0.97), xycoords="axes fraction", fontsize=10, color="black", ha="left", va="top",
                        bbox=dict(facecolor="white", edgecolor="black", boxstyle="round", pad=0.3), fontweight="bold")

# Annotate each bar with its value for electricity demand
for i, demand in enumerate(electricity_demand_monthly_average["Demand (TWh)"]):
    axes[1].annotate(f"{demand:.2f}", xy=(i, demand / 2), xytext=(0, 5), textcoords="offset points", ha="center", va="bottom",
                     bbox=dict(facecolor="white", edgecolor="black", boxstyle="round,pad=0.3"), fontsize=10, rotation=90)

# Add arrow indicating min to max month for electricity demand
min_month_electricity = months[electricity_demand_monthly_average["Demand (TWh)"].idxmin()]
max_month_electricity = months[electricity_demand_monthly_average["Demand (TWh)"].idxmax()]
min_demand_electricity = electricity_demand_monthly_average["Demand (TWh)"].min()
max_demand_electricity = electricity_demand_monthly_average["Demand (TWh)"].max()

arrow_length_electricity = max_demand_electricity - min_demand_electricity
axes[1].annotate(f"$D_{{Max}}/D_{{Min}}$ = {max_demand_electricity / min_demand_electricity:.2f}", xy=(min_month_electricity, min_demand_electricity), xytext=(min_month_electricity, max_demand_electricity),
             arrowprops=dict(facecolor="black", arrowstyle="<|-|>", lw=1.5), ha="center", va="bottom")

# Design elements for electricity plot
axes[1].set_title("Monthly Electricity Demand (TWh),1979-2018 Average", fontweight="bold")
axes[1].set_ylabel("Electricity Demand (TWh)")
axes[1].set_ylim(0, 115)
axes[1].grid(axis="y")

# Display the plots
plt.tight_layout()
plt.show()

# %% [markdown]
# **Table of Monthly Demand Fractions**\
# Now package monthly consumptions fractions into a table.

# %%
gas_demand_monthly_average.set_index("Month", inplace=True)
gas_transpose = gas_demand_monthly_average.T.drop("Demand (TWh)", axis=0)

electricity_demand_monthly_average.set_index("Month", inplace=True)
electricity_transpose = electricity_demand_monthly_average.T.drop("Demand (TWh)", axis=0)

# Merge into single table
gas_electricity_FOD = pd.concat([gas_transpose, electricity_transpose], axis=0)

gas_electricity_FOD
# Out:
# Month                    1         2         3         4         5         6   \
# FOD (Natural Gas)  0.117045  0.099058  0.102048  0.088192  0.075924  0.060364
# FOD (Electricity)  0.093035  0.084782  0.090584  0.084502  0.082558  0.075805
#
# Month                    7         8         9         10        11        12
# FOD (Natural Gas)  0.062870  0.058939  0.059977  0.079692  0.093946  0.101946
# FOD (Electricity)  0.075791  0.075984  0.076098  0.083334  0.085660  0.091867

# %% [markdown]
# Now we need to match these to the relevant yearly predictions to get the month-by-month demand by category.

# %%
def compile_filtered_data(result_dict, columns_to_print, rows_to_print):
    """Compiles specified columns of DataFrames for given rows in each sector into a single DataFrame.

    :param result_dict: Dictionary of DataFrames, one for each sector.
    :param columns_to_print: List of column names to be included.
    :param rows_to_print: List of row labels to filter by in the 'Energy Source' column.
    :return: A single DataFrame with all the compiled data.
    """
    compiled_data = []

    for sector, df in result_dict.items():
        # Filter the DataFrame
        filtered_df = df[df["Energy Source"].isin(rows_to_print)]

        # Check if the DataFrame contains the specified columns
        if all(column in filtered_df.columns for column in columns_to_print):
            # Add the sector as a column
            filtered_df["Sector"] = sector

            # Append the filtered data to the compiled_data list
            compiled_data.append(filtered_df[columns_to_print + ["Sector"]])

    # Concatenate all the dataframes in the list
    final_df = pd.concat(compiled_data)

    # Rearrange columns to put 'Sector' first
    cols = final_df.columns.tolist()
    cols = [cols[-1]] + cols[:-1]  # Move 'Sector' to the beginning
    final_df = final_df[cols]

    return final_df


# Example usage
predicted_demand_df = compile_filtered_data(result_dict, ["Energy Source", "Predicted Electricity Demand"],
                            ["Electricity", "Natural Gas", "Petroleum products", "Petroleum products (Aviation)",
                             "Petroleum products (Rail)", "Petroleum products (Road transport)",
                             "Petroleum products (Shipping)", "Renewables", "Solid / manufactured fuels"])
# predicted_demand_df

# %%
predicted_demand_df.reset_index(drop=True, inplace=True)

# %%
# Select the FOD row for Electricity.

# Loop through the Demand DataFrame and append FOD (Electricity) values to the predicted demand for electricity.
for index, row in predicted_demand_df.iterrows():
    if row["Energy Source"] == "Electricity":
        for i in range(1, 13):
            predicted_demand_df.at[index, f"{i}"] = gas_electricity_FOD.iloc[1][i] * predicted_demand_df.iloc[index, 2]

    if row["Energy Source"] == "Natural Gas":
            for i in range(1, 13):
                predicted_demand_df.at[index, f"{i}"] = gas_electricity_FOD.iloc[0][i] * predicted_demand_df.iloc[index, 2]

    if row["Energy Source"] != "Electricity" and row["Energy Source"] != "Natural Gas":
            for i in range(1, 13):
                predicted_demand_df.at[index, f"{i}"] = 1 / 12 * predicted_demand_df.iloc[index, 2]

# result_df

# %% [markdown]
# Plot predicted monthly demand totals and break columns into demand by sector and plot the results.

# %%
# Create an empty list to store the sums for each sector
sums_by_sector = []

# Loop through the sectors
for sector in sectors:
    sector_data = predicted_demand_df[predicted_demand_df["Sector"] == sector].iloc[:, 3:].sum()
    sums_by_sector.append(sector_data)

# Convert the list of sums into a DataFrame
sums_df = pd.DataFrame(sums_by_sector)

# Transpose the DataFrame to have months as columns and sectors as rows
sums_df = sums_df.T

# Assign sector names to columns
sums_df.columns = sectors

# Order the sectors by total sum (largest on the bottom)
sorted_columns = sums_df.sum(axis=0).sort_values(ascending=False).index
sums_df = sums_df[sorted_columns]

# Create an array of x positions for the bars
x = np.arange(len(months))

# Create the stacked bar plot with the specified colors
fig, ax = plt.subplots(figsize=(12, 9), dpi=200)
colors = plt.cm.get_cmap("tab20", len(sectors))
bottom = np.zeros(len(months))

for i, sector in enumerate(sums_df.columns):
    plt.bar(x, sums_df[sector], label=sector, bottom=bottom, color=colors(i))
    bottom += sums_df[sector]

# Add total labels above each column (monthly total)
monthly_totals = sums_df.sum(axis=1)
for i, total in enumerate(monthly_totals):
    plt.text(x[i], total / 2, str(round(total, 2)), ha="center", va="bottom", fontsize=10, bbox=dict(facecolor="white", edgecolor="black", boxstyle="round,pad=0.5"))

# make the arrow
arrow_size = max(monthly_totals) - min(monthly_totals)
ratio = max(monthly_totals) / min(monthly_totals)
plt.annotate(f"$D_{{Max}}/D_{{Min}}$ = {ratio:.2f}", xy=(x[int(monthly_totals.idxmin())] - 1, min(monthly_totals)), xytext=(x[int(monthly_totals.idxmin())] - 1, max(monthly_totals)),
             arrowprops=dict(facecolor="black", arrowstyle="<|-|>", lw=1.5), ha="center", va="bottom")


# Customize x labels and plot title
plt.ylabel("Electricity Demand (TWh)")
plt.title("Electricity Demand by Month (TWh)", fontweight="bold")

# Customize x labels using the 'months' array
plt.ylim(0, 115)
plt.xticks(x, months)
plt.grid(axis="y")

# Customize legend using sector names
plt.legend(sums_df.columns, loc="upper right")

# Show the plot
plt.show()
# Out:
# C:\Users\Yutong Ren\AppData\Local\Temp\ipykernel_2632\246230481.py:27: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = plt.cm.get_cmap('tab20', len(sectors))

# %%
print(monthly_totals)
# Out:
# 1     54.183061
# 2     49.981683
# 3     51.961998
# 4     48.805381
# 5     47.005943
# 6     43.483399
# 7     43.731790
# 8     43.391538
# 9     43.528907
# 10    47.610280
# 11    49.720386
# 12    52.323001
# dtype: float64

# %% [markdown]
# ## Create Daily Demand Averages

# %%
predicted_demand_monthly = monthly_totals

# %%
scale_factors = np.divide(np.array(predicted_demand_monthly), np.array(electricity_demand_monthly_average["Demand (TWh)"]))
scale_factors_df = pd.DataFrame({"scale_factors": scale_factors})
scale_factors_df
# Out:
#     scale_factors
# 0        1.729408
# 1        1.750598
# 2        1.703395
# 3        1.715062
# 4        1.690735
# 5        1.703353
# 6        1.713409
# 7        1.695747
# 8        1.698588
# 9        1.696530
# 10       1.723604
# 11       1.691280

# %%
# Create a mapping from the 'Month' to the corresponding 'scale_factors'
month_to_scale_factor = dict(enumerate(scale_factors_df["scale_factors"], start=1))

# Map each 'Month' in 'electricity_demand_daily_average' to its 'scale_factor' and multiply it with 'Demand (TWh)'
electricity_demand_daily_average["Average Demand Scaled (TWh)"] = electricity_demand_daily_average.apply(
    lambda row: row["Demand (TWh)"] * month_to_scale_factor.get(row["Month"], 1), axis=1)

electricity_demand_daily_average["Average Demand Scaled (TWh)"].sum()
# Out:
# np.float64(577.044018652649)

# %%
electricity_demand_daily_average
# Out:
#      Month  Day  Demand (TWh)  Average Demand Scaled (TWh)
# 0        1    1      1.009921                     1.746565
# 1        1    2      1.010431                     1.747447
# 2        1    3      1.009912                     1.746551
# 3        1    4      1.013472                     1.752706
# 4        1    5      1.007949                     1.743155
# ..     ...  ...           ...                          ...
# 361     12   27      1.014506                     1.715814
# 362     12   28      1.010895                     1.709707
# 363     12   29      1.013216                     1.713632
# 364     12   30      1.000511                     1.692144
# 365     12   31      1.001680                     1.694121
#
# [366 rows x 4 columns]

# %%
plt.figure(figsize=(7, 4), dpi=250)
plt.title("Daily Electricity Demand (TWh)", fontweight="bold")
plt.plot(electricity_demand_daily_average["Demand (TWh)"], label="1979-2018 Daily Average")
plt.plot(electricity_demand_daily_average["Average Demand Scaled (TWh)"], label="2050 Prediction")
plt.xlabel("Day of Year")
plt.ylabel("Average Daily Demand (TWh)")
plt.ylim(0.6, 2)
plt.grid(axis="y")
plt.legend(loc="upper right")
plt.savefig("output/Elec demand", bbox_inches="tight")

# %% [markdown]
# ## Tile Average Electricity Year

# %%
# Define the date range
start_date = "1980-01-01"
end_date = "2019-12-31"

electricity_demand_daily_average = electricity_demand_daily_average["Average Demand Scaled (TWh)"].to_numpy()


# Sample data, replace with actual values

# Create date range for 40 years including leap years
date_range = pd.date_range(start=start_date, end=end_date)


# Create a function to repeat the daily values for each year, accounting for leap years
def tile_daily_values(daily_values, dates):
    # Initialize an empty array to hold the tiled values
    tiled_values = np.zeros(len(dates))

    # Loop through each year in the date range
    current_year = dates[0].year
    leap_year_index = 0
    for i, date in enumerate(dates):
        if date.year != current_year:
            current_year = date.year
            leap_year_index = 0  # Reset index for the new year

        # Check if the current year is a leap year
        if pd.Timestamp(current_year, 12, 31).dayofyear == 366:
            # Use the full array including the leap day
            tiled_values[i] = daily_values[leap_year_index]
        else:
            # Use the array excluding the last value (leap day)
            tiled_values[i] = daily_values[leap_year_index if leap_year_index < 365 else leap_year_index - 1]

        leap_year_index += 1
        if leap_year_index == 366:  # Reset for the next year
            leap_year_index = 0

    return tiled_values


# Tile the electricity demand values across the 40 years
tiled_electricity_demand = tile_daily_values(electricity_demand_daily_average, date_range)

# %%
# Create a DataFrame with the dates and the tiled electricity demand
electricity_demand_df = pd.DataFrame({"Date": date_range, "Average Demand Scaled (TWh)": tiled_electricity_demand})

# Show the first few rows of the DataFrame to verify
# electricity_demand_df

plt.figure(figsize=(7, 4), dpi=250)
plt.plot(date_range, tiled_electricity_demand, label="tiled_electricity_demand")
plt.legend(loc="upper right")

# %% [markdown]
# # Modelling Future Electricity Supply

# %% [markdown]
# ## Baseload Capacity
#
# **Nuclear Capacity**

# %%
capacity_nuclear = 24  # GW predicted in 2050
load_factor_nuclear = 0.9  # e.g. Hinkley Point C

# Calculate annual supply
supply_nuclear_annual = capacity_nuclear * load_factor_nuclear * 24 * 365 / 1000  # TWh

# Divide annual supply values by 12 to get monthly supply
supply_nuclear_monthly = supply_nuclear_annual / 12  # TWh

supply_nuclear_daily = capacity_nuclear * load_factor_nuclear * 24 / 1000  # TWh

supply_nuclear_present = 5.9 * load_factor_nuclear * 24 * 31 / 1000

# %% [markdown]
# ## UK Wind and Solar Potential
#
# **Introduction**
#
# - Assume wind/solar mix of 80/20 and onshore/offshore mix 70/30.
# - Get potential supply data from Renewables Ninja
#     - Get the average load factor for wind and solar
# - Calculate supply per month under different levels of total installed capacity
#     - Line plot for supply per month for capacity 1,2,3 and demand for that month
#     - Show that supply is relatively insensitive to the capacity installed
#
#
# *PV Dataset*
#
# Renewables.ninja PV (hourly data, 1980-2019) - ninja_pv_country_GB_merra-2_corrected - Version: 1.3 - License: https://creativecommons.org/licenses/by-nc/4.0/ - Reference: https://doi.org/10.1016/j.energy.2016.08.060
# Units: time in UTC, other columns are capacity factors [0-1].  Bias corrected using national generation data.!
#
# *Wind Dataset*
#
# Renewables.ninja Wind (hourly data, split by on/offshore, 1980-2019) - ninja_wind_country_GB_current-merra-2_corrected - Version: 1.3 - License: https://creativecommons.org/licenses/by-nc/4.0/ - Reference: https://doi.org/10.1016/j.energy.2019.08.068
# Units: time in UTC, other columns are capacity factors [0-1]. Simulation represents 13,151 MW of capacity, of which 8,052 MW onshore and 5,100 MW offshore. Bias corrected using national generation data.!

# %%
# import data from renewables ninja

# wind
cf_gb_wind = pd.read_excel(
    "../data/ninja_wind_country_GB_current-merra-2_corrected.xlsx",
    sheet_name="ninja_wind_country_GB_current-m", usecols=[0, 1, 2, 3], skiprows=[0, 1])

# solar
cf_gb_solar = pd.read_excel(
    "../data/ninja_pv_country_GB_merra-2_corrected.xlsx",
    sheet_name="ninja_pv_country_GB_merra-2_cor", usecols=[0, 1], skiprows=[0, 1])

# %% [markdown]
# Do some basic analysis to get:
#
# - Average monthly capacity factor for:
#     - onshore wind
#     - offshore wind

# %%
hourly_solar_data = pd.DataFrame({"datetime": cf_gb_solar[cf_gb_solar.columns[0]], "cf_solar": cf_gb_solar[cf_gb_solar.columns[1]]})

# Now we'll create a DataFrame with daily averages from the hourly data
# We'll set the datetime column as the index to make resampling easier
hourly_solar_data.set_index("datetime", inplace=True)

# Resampling the data to daily frequency and calculating the mean for each day
cf_solar_daily = hourly_solar_data.resample("D").mean()

# Resetting the index to get the datetime back as a column
cf_solar_daily.reset_index(inplace=True)

# cf_solar_daily  # Display the first few rows of the daily averages DataFrame

# %%
hourly_wind_data = pd.DataFrame({"datetime": cf_gb_wind[cf_gb_wind.columns[0]], "cf_national": cf_gb_wind[cf_gb_wind.columns[1]]})

# Now we'll create a DataFrame with daily averages from the hourly data
# We'll set the datetime column as the index to make resampling easier
hourly_wind_data.set_index("datetime", inplace=True)

# Resampling the data to daily frequency and calculating the mean for each day
cf_wind_daily = hourly_wind_data.resample("D").mean()

# Resetting the index to get the datetime back as a column
cf_wind_daily.reset_index(inplace=True)

# cf_wind_daily  # Display the first few rows of the daily averages DataFrame

# %%
hourly_offshore_data = pd.DataFrame({"datetime": cf_gb_wind[cf_gb_wind.columns[0]], "cf_offshore": cf_gb_wind[cf_gb_wind.columns[2]]})

# Now we'll create a DataFrame with daily averages from the hourly data
# We'll set the datetime column as the index to make resampling easier
hourly_offshore_data.set_index("datetime", inplace=True)

# Resampling the data to daily frequency and calculating the mean for each day
cf_offshore_daily = hourly_offshore_data.resample("D").mean()

# Resetting the index to get the datetime back as a column
cf_offshore_daily.reset_index(inplace=True)

# cf_offshore_daily  # Display the first few rows of the daily averages DataFrame

# %%
hourly_onshore_data = pd.DataFrame({"datetime": cf_gb_wind[cf_gb_wind.columns[0]], "cf_onshore": cf_gb_wind[cf_gb_wind.columns[3]]})

# Now we'll create a DataFrame with daily averages from the hourly data
# We'll set the datetime column as the index to make resampling easier
hourly_onshore_data.set_index("datetime", inplace=True)

# Resampling the data to daily frequency and calculating the mean for each day
cf_onshore_daily = hourly_onshore_data.resample("D").mean()

# Resetting the index to get the datetime back as a column
cf_onshore_daily.reset_index(inplace=True)

# cf_onshore_daily  # Display the first few rows of the daily averages DataFrame

# %%
plt.figure(figsize=(12, 6), dpi=200)
plt.title("Capacity Factors, 1980-2019", fontweight="bold")
plt.xlabel("Day")
plt.ylabel("Daily-Averaged Capacity Factor (0-1)")
plt.plot(cf_offshore_daily["cf_offshore"][::4], label="offshore", linewidth=0.3)
plt.plot(cf_onshore_daily["cf_onshore"][::4], label="onshore", linewidth=0.3)
plt.plot(cf_solar_daily["cf_solar"][::4], label="solar", linewidth=0.3)
plt.legend()

# %% [markdown]
# # Optimal Solar-Wind Mix

# %%
# daily renewables output in TWh


def wind_solar_nuclear_output(cf_offshore, cf_onshore, cf_solar, fraction_solar, capacity_renewables, daily_supply_nuclear):
    """Output renewables generation corresponding to the...
    ...datasets of cf_wind and cf_solar and some critical assumptions
    """
    S_offshore = capacity_renewables * (1 - fraction_solar) * 0.7 * cf_offshore * 24 / 1000  # TWh

    S_onshore = capacity_renewables * (1 - fraction_solar) * 0.3 * cf_onshore * 24 / 1000

    S_solar = capacity_renewables * fraction_solar * cf_solar * 24 / 1000  # TWh

    S_daily = S_offshore + S_onshore + S_solar + daily_supply_nuclear

    return S_daily

# %%
# 270 GW renewable
S = wind_solar_nuclear_output(cf_offshore_daily["cf_offshore"], cf_onshore_daily["cf_onshore"], cf_solar_daily["cf_solar"], 0.2, 270, 0)

plt.figure(figsize=(12, 6), dpi=250)
plt.title("Capacity Factors, 1980-2019", fontweight="bold")
plt.xlabel("Day")
plt.ylabel("Energy (TWh)")
plt.plot(S[::8], linewidth=0.4, label="Supply")
plt.plot(tiled_electricity_demand, linewidth=0.4, label="Demand")
plt.legend(loc="upper right")

# %%
fraction_solar_array = np.linspace(0, 1, 15)


plt.figure(figsize=(7, 4), dpi=250)
plt.title("Optimal Renewable Mix", fontweight="bold")
plt.xticks(np.arange(0, 1.1, 0.1), fontsize=4)

plt.xlabel("Solar Power Capacity/Renewable Capacity")
plt.ylabel("Demand/Unmet Demand")
plt.grid()
# plt.ylim(-.1,0.15)

for renewable_capacity in [200, 250, 280, 300]:

    # Create an empty list to store DataFrames
    dfs_storage = []

    # Loop through renewable_capacities
    for fraction_solar in fraction_solar_array:

        # Calculate the net supply for each capacity
        S = wind_solar_nuclear_output(cf_offshore_daily["cf_offshore"], cf_onshore_daily["cf_onshore"], cf_solar_daily["cf_solar"], fraction_solar, 150, supply_nuclear_daily)

        D = tiled_electricity_demand

        # Create a DataFrame for the current capacity
        df = pd.DataFrame({f"S-D,RC={renewable_capacity}GW,FS={np.round(fraction_solar, 2)}": S - D, f"D,RC={renewable_capacity}GW,FS={np.round(fraction_solar, 2)}": D})

        # Append the DataFrame to the list
        dfs_storage.append(df)

    # Concatenate the list of DataFrames along the columns (axis=1)
    S_D_df = pd.concat(dfs_storage, axis=1)

    unmet_demand_array = []

    for fraction_solar in fraction_solar_array:

        column_name_S_D = f"S-D,RC={renewable_capacity}GW,FS={np.round(fraction_solar, 2)}"

        column_name_D = f"D,RC={renewable_capacity}GW,FS={np.round(fraction_solar, 2)}"

        unmet_D_sum = S_D_df[S_D_df[column_name_S_D] < 0][column_name_S_D].sum()

        D_sum = S_D_df[column_name_D].sum()

        unmet_demand_fraction = D_sum / abs(unmet_D_sum)

        unmet_demand_array.append(unmet_demand_fraction)

    plt.plot(fraction_solar_array, unmet_demand_array, "-", label=f"Renewable Capacity = {renewable_capacity} GW")
    plt.legend(fontsize=6)

# %% [markdown]
# # Average Annual Supply for 0, 12, 24 GW Nuclear

# %% [markdown]
# ## Renewable Capacities and Renewable Ratios Assumptions

# %%
# solar/wind and onshore/offshore assumptions
share_wind = 0.8
share_solar = 0.2
share_wind_onshore = 0.3
share_wind_offshore = 0.7

# A list of different renewable capacity values
# 24 GW scenario: [140,150,160,170,180,190,200,210,220]
# 12 GW scenario: [180,190,200,210,220,230,240,250,260]
# 0 GW scenario: [250,260,270,280,290,300,310,320,330]

# renewable_capacities_removal = [450,460,470,480,490,500] # GW

# %%
# get average CF values
cf_offshore = cf_offshore_daily["cf_offshore"].mean()
cf_onshore = cf_onshore_daily["cf_onshore"].mean()
cf_solar = cf_solar_daily["cf_solar"].mean()


# Renewables Weighted CF
cf_renewables = share_solar * cf_solar + share_wind * (share_wind_offshore * cf_offshore + share_wind_onshore * cf_onshore)

# %%
def average_supply(renewable_capacity, capacity_nuclear_1, capacity_nuclear_2, capacity_nuclear_3, cf_renewables, cf_nuclear):
    """Return average supply from renewables and nuclear for 3 different baseload scenarios.
    """
    # supply in TWh
    S_renewables = renewable_capacity * cf_renewables * 24 * 365 / 1000
    S_nuclear_1 = capacity_nuclear_1 * cf_nuclear * 24 * 365 / 1000
    S_nuclear_2 = capacity_nuclear_2 * cf_nuclear * 24 * 365 / 1000
    S_nuclear_3 = capacity_nuclear_3 * cf_nuclear * 24 * 365 / 1000

    return S_renewables + S_nuclear_1, S_renewables + S_nuclear_2, S_renewables + S_nuclear_3

# %%
# a new set of capacities for removal
# all_renewable_capacities_removal_12 = np.arange(200,410,10)
all_renewable_capacities_removal_12 = np.arange(0, 510, 10)

# %%
# all_renewable_capacities = [120,130,140,150,160,170,180,190,200,210,220,230,240,250,260,270,280,290,300,310,320,330]
nuclear_12 = []

for capacity in all_renewable_capacities_removal_12:
    nuclear_12.append(average_supply(capacity, 0, 12, 24, cf_renewables, load_factor_nuclear)[1])

# %% [markdown]
# # Modelling S-D

# %%
# daily renewables output in TWh


def renewables_output(cf_offshore, cf_onshore, cf_solar, capacity_renewables, capacity_nuclear):
    """Output renewables generation corresponding to the...
    ...datasets of cf_wind and cf_solar and some critical assumptions
    """
    S_offshore = cf_offshore * capacity_renewables * share_wind * share_wind_offshore * 24 / 1000  # TWh
    S_onshore = cf_onshore * capacity_renewables * share_wind * share_wind_onshore * 24 / 1000  # TWh
    S_solar = cf_solar * capacity_renewables * share_solar * 24 / 1000  # TWh
    S_nuclear = load_factor_nuclear * capacity_nuclear * 24 / 1000

    S_daily = S_offshore + S_onshore + S_solar + S_nuclear

    return S_daily

# %% [markdown]
# ## Net Energy Balance $S-D$
#
# **Daily Difference Between Supply and Demand**
# - Consider different scenarios of installed renewable capacity.
# - Plot the energy surplus/shortfall for each month
# - Calculate average annual shortfall/surplus
# - (optimize for installed capacity?)

# %%
# Create an empty list to store DataFrames
dfs_0 = []
dfs_12 = []

# Loop through renewable_capacities
for capacity in all_renewable_capacities_removal_12:
    # Calculate the net supply for each capacity
    net_supply_0 = renewables_output(cf_offshore_daily["cf_offshore"], cf_onshore_daily["cf_onshore"], cf_solar_daily["cf_solar"], capacity, 0) - tiled_electricity_demand
    net_supply_12 = renewables_output(cf_offshore_daily["cf_offshore"], cf_onshore_daily["cf_onshore"], cf_solar_daily["cf_solar"], capacity, 12) - tiled_electricity_demand

    # Create a DataFrame for the current capacity
    df_0 = pd.DataFrame({f"S-D(TWh),Ren={capacity}GW": net_supply_0})
    df_12 = pd.DataFrame({f"S-D(TWh),Ren={capacity}GW": net_supply_12})

    # Append the DataFrame to the list
    dfs_0.append(df_0)
    dfs_12.append(df_12)

# Concatenate the list of DataFrames along the columns (axis=1)
net_supply_df_0 = pd.concat(dfs_0, axis=1)
net_supply_df_12 = pd.concat(dfs_12, axis=1)

# %% [markdown]
# ## Shortage and Surplus Fractions

# %%
caparray = np.arange(0, 510, 10)
balance = []
demandunmet_0 = []
demandunmet_12 = []
for capacity in caparray:
    demandunmet_0.append(len(net_supply_df_0[net_supply_df_0[f"S-D(TWh),Ren={capacity}GW"] < 0][f"S-D(TWh),Ren={capacity}GW"]))
    demandunmet_12.append(len(net_supply_df_12[net_supply_df_12[f"S-D(TWh),Ren={capacity}GW"] < 0][f"S-D(TWh),Ren={capacity}GW"]))

# %%
nuclear = 12
plt.figure(figsize=(7, 4), dpi=250)
plt.plot(demandunmet_0, caparray, label="0GW Nuclear", linewidth=2)
plt.plot(demandunmet_12, caparray, label="12GW Nuclear", linewidth=2)
plt.axhline(nuclear, linestyle="dashed", label="Nuclear Baseload", color="k", linewidth=1)

plt.xlabel("Day in 40 years")
plt.ylabel("Annual Renewable Supply (GW)")
plt.grid()
plt.legend()
plt.title("Energy Deficit Days Over 40 Years")

plt.savefig("output/Deficit", bbox_inches="tight")

# %%
n_days = len(net_supply_df_12)


sum_shortages = []
sum_surpluses = []

# n_days = len(daily_demand_df)

for capacity in all_renewable_capacities_removal_12:
    sum_shortages.append(net_supply_df_12[net_supply_df_12[f"S-D(TWh),Ren={capacity}GW"] < 0][f"S-D(TWh),Ren={capacity}GW"].sum() / n_days)
    sum_surpluses.append(net_supply_df_12[net_supply_df_12[f"S-D(TWh),Ren={capacity}GW"] > 0][f"S-D(TWh),Ren={capacity}GW"].sum() / n_days)

# Calculate the minimum and maximum values for each line
min_shortage = min(sum_shortages)
max_shortage = max(sum_shortages)
min_surplus = min(sum_surpluses)
max_surplus = max(sum_surpluses)

# Calculate the percentage difference
shortage_difference = max_shortage - min_shortage
surplus_difference = max_surplus - min_surplus

# Plot the lines
plt.figure(figsize=(8, 4), dpi=250)
plt.plot(all_renewable_capacities_removal_12, sum_shortages, "-o", linewidth=2.5, label="Sum of Shortages")
plt.plot(all_renewable_capacities_removal_12, sum_surpluses, "-o", linewidth=2.5, label="Sum of Surpluses")

# Add dashed horizontal lines at the maximum and minimum values of each line
plt.axhline(max_shortage, color="red", linestyle="--")
plt.axhline(min_shortage, color="red", linestyle="--")
plt.axhline(max_surplus, color="green", linestyle="--")
plt.axhline(min_surplus, color="green", linestyle="--")

# Annotate the plot with percentage difference information
plt.text(all_renewable_capacities_removal_12[-1] - 0.5, (max_shortage + min_shortage) / 2, f"∆ = {shortage_difference:.2f}TWh",
         ha="right", va="center", bbox=dict(boxstyle="round", facecolor="white", edgecolor="black"), fontsize=8)
plt.text(all_renewable_capacities_removal_12[-1] - 0.5, (max_surplus + min_surplus) / 2, f"∆ = {surplus_difference:.2f}TWh",
         ha="right", va="center", bbox=dict(boxstyle="round", facecolor="white", edgecolor="black"), fontsize=8)

# Add arrows to illustrate the difference
plt.annotate("", xy=(all_renewable_capacities_removal_12[-1], max_shortage), xytext=(all_renewable_capacities_removal_12[-1], min_shortage),
             arrowprops=dict(facecolor="red", arrowstyle="<->"))
plt.annotate("", xy=(all_renewable_capacities_removal_12[-1], max_surplus), xytext=(all_renewable_capacities_removal_12[-1], min_surplus),
             arrowprops=dict(facecolor="green", arrowstyle="<->"))

plt.ylabel("Energy Surplus/Shortage (TWh)")
plt.xlabel("Renewable Capacity (GW)")
# plt.ylim(min_shortage*1.3,-(min_shortage)*1.1)
plt.title("Energy Surplus/Shortage (TWh), 1980-2019 Monthly Average", fontweight="bold")
plt.grid(axis="y")
plt.legend(loc="upper left")
plt.show()

# %%
count_shortages_12 = []
count_surpluses_12 = []

for capacity in all_renewable_capacities_removal_12:
    count_shortages_12.append(net_supply_df_12[net_supply_df_12[f"S-D(TWh),Ren={capacity}GW"] < 0][f"S-D(TWh),Ren={capacity}GW"].count() / n_days)
    count_surpluses_12.append(net_supply_df_12[net_supply_df_12[f"S-D(TWh),Ren={capacity}GW"] >= 0][f"S-D(TWh),Ren={capacity}GW"].count() / n_days)

# Plot the lines
plt.figure(figsize=(7, 4), dpi=250)

# 12 GW Nuclear
plt.plot(all_renewable_capacities_removal_12, count_shortages_12, "-", linewidth=2.5, label="$S-D<0$, 12 GW Nuclear", color="b")
# plt.plot(renewable_capacities, count_surpluses_12, '--',linewidth=2.5,label='$S-D\geq0$, 12 GW Nuclear',color='b')

plt.ylabel("Fraction of Days (01/01/1980 to 31/12/2019)", fontsize=8)
plt.xlabel("Installed Renewable Capacity (GW)", fontsize=8)
plt.yticks(fontsize=6)
plt.xticks(all_renewable_capacities_removal_12, fontsize=6)
plt.ylim(0, 1)
plt.title("Fraction of Days with an Energy Shortage", fontweight="bold", fontsize=12)
plt.grid(axis="y")
plt.legend(loc="upper right", fontsize=8)
plt.show()

# %%
count_demand_met_12 = []

for capacity in all_renewable_capacities_removal_12:
      count_demand_met_12.append(net_supply_df_12[net_supply_df_12[f"S-D(TWh),Ren={capacity}GW"] == 0][f"S-D(TWh),Ren={capacity}GW"].count() / n_days)

# %% [markdown]
# # Energy Storage

# %% [markdown]
# ## Storage Levels and Remnant Energies

# %%
yearly = tiled_electricity_demand[:365]
np.sum(yearly)
# Out:
# np.float64(575.3498978009909)

# %%
import warnings

warnings.simplefilter(action="ignore", category=FutureWarning)

# %%
e_in = 0.74  # electrolysis
e_out = 0.55  # electricity generation from hydrogen

# %% [markdown]
# # Modification

# %%
# with efficient use of residual energy, DAC capacity
# Storage Volume assumptions
L_max = 71.0  # TWh
L_0 = L_max
# Electrolyser Power Assumptions
P_ele = 50  # GW
E_max = P_ele * 24 / 1000  # TWh
# DAC capacity
DAC_cap = 27.0  # GW
DAC_max = DAC_cap * 24 / 1000  # TWh
part_renewable_capacities_removal = [250]

for capacity in part_renewable_capacities_removal:
    column_name_S_D = f"S-D(TWh),Ren={capacity}GW"
    column_name_L = f"L (TWh),RC={capacity}GW"
    column_name_R = f"R_ccs (TWh),RC={capacity}GW"
    column_name_RDAC = f"R_dac (TWh),RC={capacity}GW"

    net_supply_df_12[column_name_L] = 0.0  # Initialize column with zeros
    net_supply_df_12[column_name_R] = 0.0
    net_supply_df_12[column_name_RDAC] = 0.0

    # Month 1

    # 1) S-D < 0 (net shortage) ##

    # a) Storage was emptied
    if net_supply_df_12[column_name_S_D][0] < 0 and net_supply_df_12[column_name_S_D][0] + L_0 * e_out < 0:

        net_supply_df_12[column_name_L].iloc[0] = 0

    # b) Storage prevented a shortage
    if net_supply_df_12[column_name_S_D][0] < 0 and net_supply_df_12[column_name_S_D][0] + L_0 * e_out > 0:

        net_supply_df_12[column_name_L].iloc[0] = L_0 + net_supply_df_12[column_name_S_D][0] / e_out

    # 2) S-D > 0 (net surplus and sufficient electrolyser power) ####

    # a) Storage is being filled, but there is not enough energy surplus to fill it entirely
    if net_supply_df_12[column_name_S_D][0] > 0 and net_supply_df_12[column_name_S_D][0] < E_max and net_supply_df_12[column_name_S_D][0] * e_in <= L_max:

        net_supply_df_12[column_name_L].iloc[0] = L_0 + net_supply_df_12[column_name_S_D][0] * e_in

    # b) Storage has been filled fully
    if net_supply_df_12[column_name_S_D][0] > 0 and net_supply_df_12[column_name_S_D][0] < E_max and L_0 + net_supply_df_12[column_name_S_D][0] * e_in > L_max:
        print("Storage is full, sufficient ele")

        net_supply_df_12[column_name_L].iloc[0] = L_max
        Used = (L_max - L_0) / e_in  # Energy used to fill in the storage
        net_supply_df_12[column_name_R].iloc[0] = net_supply_df_12[column_name_S_D][0] - Used
        if net_supply_df_12[column_name_R][0] < DAC_max:
            net_supply_df_12[column_name_RDAC].iloc[0] = net_supply_df_12[column_name_R][0]
        else:
            net_supply_df_12[column_name_RDAC].iloc[0] = DAC_max

    # 3) S-D > 0 (net surplus and insufficient electrolyser power) ####

    # a) Storage is being filled, but there is not enough energy surplus to fill it entirely
    if net_supply_df_12[column_name_S_D][0] > 0 and net_supply_df_12[column_name_S_D][0] >= E_max and L_0 + E_max * e_in <= L_max:

        net_supply_df_12[column_name_L].iloc[0] = L_0 + E_max * e_in

    # b) Storage has been filled fully
    if net_supply_df_12[column_name_S_D][0] > 0 and net_supply_df_12[column_name_S_D][0] >= E_max and L_0 + E_max * e_in > L_max:
        print("Storage is full, insufficient ele")
        net_supply_df_12[column_name_L].iloc[0] = L_max
        Used = (L_max - L_0) / e_in
        if Used <= E_max:
            net_supply_df_12[column_name_R].iloc[0] = net_supply_df_12[column_name_S_D][0] - Used
            if net_supply_df_12[column_name_R][0] < DAC_max:
                net_supply_df_12[column_name_RDAC].iloc[0] = net_supply_df_12[column_name_R][0]
            else:
                net_supply_df_12[column_name_RDAC].iloc[0] = DAC_max
        if Used > E_max:
            net_supply_df_12[column_name_R].iloc[0] = net_supply_df_12[column_name_S_D][0] - E_max
            if net_supply_df_12[column_name_R][0] < DAC_max:
                net_supply_df_12[column_name_RDAC].iloc[0] = net_supply_df_12[column_name_R][0]
            else:
                net_supply_df_12[column_name_RDAC].iloc[0] = DAC_max

    # now step forward in time from day 2 to day 14,610
    for i in range(1, len(net_supply_df_12)):

        # 1) S-D < 0 (net shortage) ####

        # a) Storage was emptied
        if net_supply_df_12[column_name_S_D][i] <= 0 and net_supply_df_12[column_name_S_D][i] + net_supply_df_12[column_name_L][i - 1] * e_out <= 0:

            net_supply_df_12[column_name_L][i] = 0

        # b) Storage prevented a shortage
        if net_supply_df_12[column_name_S_D][i] <= 0 and net_supply_df_12[column_name_S_D][i] + net_supply_df_12[column_name_L][i - 1] * e_out > 0:

            net_supply_df_12[column_name_L][i] = net_supply_df_12[column_name_L][i - 1] + (net_supply_df_12[column_name_S_D][i]) / e_out

        # 2) S-D > 0 (net surplus and sufficient electrolyser power) ####

        # a) Storage is being filled, but there is not enough energy surplus to fill it entirely
        if net_supply_df_12[column_name_S_D][i] > 0 and net_supply_df_12[column_name_S_D][i] * e_in < L_max and net_supply_df_12[column_name_S_D][i] <= E_max:

            net_supply_df_12[column_name_L][i] = net_supply_df_12[column_name_L][i - 1] + net_supply_df_12[column_name_S_D][i] * e_in

        # b) Storage has been filled fully
        if net_supply_df_12[column_name_S_D][i] > 0 and net_supply_df_12[column_name_L][i - 1] + net_supply_df_12[column_name_S_D][i] * e_in >= L_max and net_supply_df_12[column_name_S_D][i] <= E_max:

            net_supply_df_12[column_name_L][i] = L_max
            Used = (L_max - net_supply_df_12[column_name_L][i - 1]) / e_in  # Energy used to fill in the storage
            net_supply_df_12[column_name_R][i] = net_supply_df_12[column_name_S_D][i] - Used
            if net_supply_df_12[column_name_R][i] <= DAC_max:
                net_supply_df_12[column_name_RDAC][i] = net_supply_df_12[column_name_R][i]
            else:
                net_supply_df_12[column_name_RDAC][i] = DAC_max
            # print(f'i={i}, {net_supply_df[column_name_L][i]}, Storage is full, sufficient ele')

        # 3) S-D > 0 (net surplus and insufficient electrolyser power) ####

        # a) Storage is being filled, but there is not enough energy surplus to fill it entirely
        if net_supply_df_12[column_name_S_D][i] > 0 and net_supply_df_12[column_name_L][i - 1] + E_max * e_in < L_max and net_supply_df_12[column_name_S_D][i] > E_max:

            net_supply_df_12[column_name_L][i] = net_supply_df_12[column_name_L][i - 1] + E_max * e_in

        # b) Storage has been filled fully

        if net_supply_df_12[column_name_S_D][i] > 0 and net_supply_df_12[column_name_L][i - 1] + E_max * e_in >= L_max and net_supply_df_12[column_name_S_D][i] > E_max:
            # print(f'i={i}, {net_supply_df[column_name_L][i]}, Storage is full, insufficient ele')

            net_supply_df_12[column_name_L][i] = L_max
            Used = (L_max - net_supply_df_12[column_name_L][i - 1]) / e_in  # Energy used to fill in the storage
            if Used <= E_max:
                net_supply_df_12[column_name_R][i] = net_supply_df_12[column_name_S_D][i] - Used
                if net_supply_df_12[column_name_R][i] <= DAC_max:
                    net_supply_df_12[column_name_RDAC][i] = net_supply_df_12[column_name_R][i]
                else:
                    net_supply_df_12[column_name_RDAC][i] = DAC_max
            if Used > E_max:
                net_supply_df_12[column_name_R][i] = net_supply_df_12[column_name_S_D][i] - E_max
                if net_supply_df_12[column_name_R][i] <= DAC_max:
                        net_supply_df_12[column_name_RDAC][i] = net_supply_df_12[column_name_R][i]
                else:
                    net_supply_df_12[column_name_RDAC][i] = DAC_max

arr_dac = []
for i in net_supply_df_12[column_name_L]:
    arr_dac.append(i)
# minimum storage (must be >20)
print(f"minimum stoarge is {min(arr_dac)}")
# DAC energy
print(f"DAC energy is {net_supply_df_12[f'R_dac (TWh),RC={part_renewable_capacities_removal[0]}GW'].sum() / len(net_supply_df_12) * 365}")

dac_capacity = 0
for i in range(len(net_supply_df_12)):
    if net_supply_df_12[f"R_dac (TWh),RC={part_renewable_capacities_removal[0]}GW"][i] > 0:
        dac_capacity += 1
    capacity_factor = dac_capacity / len(net_supply_df_12) * 100
print(f"Capacity Factor is {capacity_factor}")
# Out:
# Storage is full, sufficient ele
# minimum stoarge is 20.169272457572283
# DAC energy is 38.479115167862105
# Capacity Factor is 19.021218343600275

# %%
# meet L>20
plt.figure(figsize=(7, 4), dpi=200)
plt.plot(net_supply_df_12[f"L (TWh),RC={part_renewable_capacities_removal[0]}GW"], color="g", linewidth=0.3, label="Energy in Storage")
plt.ylim(0, L_max * 1.1)
plt.grid(axis="y")
plt.xlabel("Day in 40 years")
plt.ylabel("Energy (TWh)")
plt.title("Amount of Energy in Storage over 40 years")
plt.axhline(L_max, linestyle="dashed", color="r", label="Minimum Storage Capacity")
plt.axhline(20, linestyle="dashed", color="b", label="Threshold Energy in Storage")
plt.legend()
plt.savefig("output/Fluctuation in Energy Storage sus")

# %%
# 24GW nuclear & DAC capacity limit
plt.figure(figsize=(7, 4), dpi=200)

# blue: energy used for DAC
# green: energy exceeded the limit (discarded
y = np.arange(0, 14610, 1)
# plt.scatter(y,np.array(net_supply_df_12[f'R_ccs (TWh),RC={part_renewable_capacities_removal[0]}GW']),color='g',linewidth=0.1)
plt.plot(net_supply_df_12[f"R_ccs (TWh),RC={part_renewable_capacities_removal[0]}GW"], color="g", linewidth=0.1, label="Residual Energy")
plt.plot(net_supply_df_12[f"R_dac (TWh),RC={part_renewable_capacities_removal[0]}GW"], color="b", linewidth=0.1, label="DAC Energy")
plt.grid(axis="y")
plt.xlabel("Day in 40 years")
plt.ylabel("Energy (TWh)")
plt.axhline(DAC_max, linestyle="dashed", color="r", label="Maximum DAC Energy")
plt.title("DAC Energy Utilization from Residual Energy")
plt.legend(fontsize=7)
plt.savefig("output/Res vs DAC", bbox_inches="tight")

# %%
# original
print(net_supply_df_12[f"R_ccs (TWh),RC={part_renewable_capacities_removal[0]}GW"])
# Out:
# 0        0.078293
# 1        0.000000
# 2        0.762533
# 3        1.108496
# 4        1.512813
#            ...
# 14605    0.000000
# 14606    0.177972
# 14607    1.065621
# 14608    0.381194
# 14609    0.000000
# Name: R_ccs (TWh),RC=250GW, Length: 14610, dtype: float64

# %%
# modify
print(net_supply_df_12[f"R_dac (TWh),RC={part_renewable_capacities_removal[0]}GW"])
# Out:
# 0        0.078293
# 1        0.000000
# 2        0.648000
# 3        0.648000
# 4        0.648000
#            ...
# 14605    0.000000
# 14606    0.177972
# 14607    0.648000
# 14608    0.381194
# 14609    0.000000
# Name: R_dac (TWh),RC=250GW, Length: 14610, dtype: float64

# %% [markdown]
# # Carbon Capture and Storage
#
# Demand for energy sourced from fossil-fuels will persist at $200-400 \text{ TWh/year}$. How many tons of $CO_2$ emissions does that translate into?

# %% [markdown]
# ## $CO_2$ Tonnage by Sector (2050E)

# %%
# plot predicted remnant fossil fuel emission masses

# Sum up the Predicted Electricity Demand and errors for every sector
predicted_c02_mass_sums = {sector: df["CO2 (mt)"].sum() for sector, df in results.items()}

# Summing up the total predicted electricity demand across all sectors
total_c02_mass = sum(predicted_c02_mass_sums.values())

# Plotting the results with error bars
plt.figure(figsize=(12, 6), dpi=200)
bars = plt.bar(predicted_c02_mass_sums.keys(), predicted_c02_mass_sums.values(), color="grey")

# Add text on each bar in boxes and total sum as text in top left corner
for bar in bars:  # (sector, error) in zip(bars, total_errors_electricity.items()):
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, yval, f"{round(yval, 2)}", ha="center", va="bottom", bbox=dict(facecolor="white", edgecolor="black", boxstyle="round,pad=0.5"))


# Display total
plt.text(0.02, 0.95, f"Total = {round(total_c02_mass, 2)} mtCO2", transform=plt.gca().transAxes, ha="left", va="top", bbox=dict(facecolor="white", edgecolor="black", boxstyle="round,pad=0.5", alpha=0.85), fontweight="bold")


# Display total sum of all bars in the top left corner
plt.grid(axis="y")
plt.title("Predicted Remnant Fossil Fuel Emissions by Sector (mtCO$_2$)", fontweight="bold")
plt.ylabel("Remnant CO$_2$ Emissions (mtCO$_2$)")
plt.xticks(rotation=45)
plt.ylim(0, total_c02_mass)
plt.show()
