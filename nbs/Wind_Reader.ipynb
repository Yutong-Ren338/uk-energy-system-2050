# %%
from src.ninja_2025_wind_plots import plot_ninja_2025_wind_power
#https://www.sciencedirect.com/science/article/pii/S0140988325001641

fig, ax, series = plot_ninja_2025_wind_power(
    wind_type="onshore",
    region_code=["UKC1", "UKC2"],
    start="2016-01-01",
    end="2016-12-31",
    resample="D",
    capacity_gw=0,  # used only if Dataset_SE.dta lacks the region/year
    dataset_year=2016,  # latest available if omitted
)
fig.show()
# Out:
# C:\Users\Yutong Ren\AppData\Local\Temp\ipykernel_77012\1916750684.py:12: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig, ax, series = plot_ninja_2025_wind_power(
    wind_type="onshore",
    include_all_regions=True,  # plot all UK regions
    start="2016-01-01",
    end="2016-12-31",
    resample="D",
    capacity_gw=0,      # used only when dataset lacks a region
    dataset_year=2016,
    figsize=(14, 7),
)
fig.show()
# Out:
# C:\Users\Yutong Ren\AppData\Local\Temp\ipykernel_77012\2380664081.py:11: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# c:\Users\Yutong Ren\Desktop\Y4\Y4-research-project\UK-Energy-Modelling-Update-main\UK-Energy-Modelling-Update-main\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: constrained_layout not applied because axes sizes collapsed to zero.  Try making figure larger or Axes decorations smaller.
#   fig.canvas.print_figure(bytes_io, **kw)
